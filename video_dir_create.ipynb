# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os

# %%
# Directory containing video files

input_dir = "C:/root/STUDY/ICT Assignments pdf/internship/video directory"
output_dir = "C:/root/STUDY/ICT Assignments pdf/internship/video directory/extracted_frames_1"

# %%
# Recursively find all video files in the input directory for frame extraction 


for root, dirs, files in os.walk(input_dir):
    for file in files:
        if file.endswith((".mp4", ".avi", ".mkv", ".mov")):  # Add other video file extensions if needed
            video_path = os.path.join(root, file)
            video_name = os.path.splitext(file)[0]
            video_output_dir = os.path.join(output_dir, video_name)
            os.makedirs(video_output_dir, exist_ok=True)
            
            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = 0
            
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                
                # Name the frame based on the video file's name
                frame_path = os.path.join(video_output_dir, f"{video_name}_frame_{frame_count:04d}.jpg")
                cv2.imwrite(frame_path, frame)
                frame_count += 1
            
            cap.release()
            print(f"Extracted {frame_count} frames from {video_name}.")
            
cv2.destroyAllWindows()
# Out:
# Extracted 131 frames from nithin.
# Extracted 224 frames from sarath.
# Extracted 141 frames from sethu.

# %%
import cv2 # to handle image files
import matplotlib.pyplot as plt # For visualisation
import numpy as np # For arithmetic operation
from PIL import Image # For image processing
import os

# %%
path = "C:/root/STUDY/ICT Assignments pdf/internship/video directory/extracted_frames_1" # path to dataset
classes=['nithin','sarath', 'sethu'] # target classes

for i,cat in enumerate(classes):
  plt.subplot(1,3,i+1) # subplot indices start from 1
  images = os.listdir(f'{path}/{cat}') # listing the items inside the directory, image names as list
  test_image=cv2.imread(f'{path}/{cat}/{images[2]}') # reading the image file
  plt.imshow(test_image) # displaying the image
  plt.title(cat) # set the title
  plt.axis('off') # set the axis off
plt.show()
